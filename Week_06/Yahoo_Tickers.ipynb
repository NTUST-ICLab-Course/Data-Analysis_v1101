# %% [markdown]
# # 如何取得股票每日的開、收盤資料
#
# 2021-10-24
#
# 參考以下兩資料：
# ## 1. [Day21]Pandas就能輕易將資料視覺化！
# https://ithelp.ithome.com.tw/articles/10196571
#
# ## 2. [Python]初心者筆記8(以pandas熊貓套件pandas_datareader快速讀取股票資料)
# https://dotblogs.com.tw/kevinya/2018/06/07/103259
# 但我試了 morningstar 很像有問題
#
#
# tickers (股票代碼):
# - F – Facebook (FB) · A – Apple (AAPL) · A – Amazon (AMZN) · N – Netflix (NFLX) · G – Google (GOOG and GOOGL)
# - 台灣：2330.TW, 0050.TW, 2317.TW
# - crypto currency: BTC-USD, ETH-USD, ETH-BTC

# %%
import pandas as pd

# %% [markdown]
# ## <span style="color:blue"> Remote Data Access </span>
#
# *Functions from pandas_datareader.data and pandas_datareader.wb extract data from various Internet sources into a pandas DataFrame.*
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-yahoo

# %%
from pandas_datareader import data
import pandas_datareader.data as web

# %% [markdown]
# ## <span style="color:red"> 我們來看股票的歷史記錄走勢 </span>

# %%
import pandas_datareader.data as web
all_data = {ticker: web.get_data_yahoo(ticker)
            for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG', 'TSM', '2330.TW', '2317.TW']}

price = pd.DataFrame({ticker: data['Adj Close']
                     for ticker, data in all_data.items()})
volume = pd.DataFrame({ticker: data['Volume']
                      for ticker, data in all_data.items()})

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
type(all_data)
# Out:
# dict

# %%
all_data.keys()
# Out:
# dict_keys(['AAPL', 'IBM', 'MSFT', 'GOOG', 'TSM', '2330.TW', '2317.TW'])

# %%
type(all_data["AAPL"])
# Out:
# pandas.core.frame.DataFrame

# %%
all_data["AAPL"]
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2016-10-25   29.590000   29.327499   29.487499   29.562500  192516000.0
# 2016-10-26   28.924999   28.327499   28.577499   28.897499  264536800.0
# 2016-10-27   28.965000   28.525000   28.847500   28.620001  138248000.0
# 2016-10-28   28.802500   28.362499   28.467501   28.430000  151446800.0
# 2016-10-31   28.557501   28.299999   28.412500   28.385000  105677600.0
# ...                ...         ...         ...         ...          ...
# 2021-10-18  146.839996  143.160004  143.449997  146.550003   85589200.0
# 2021-10-19  149.169998  146.550003  147.009995  148.759995   76378900.0
# 2021-10-20  149.750000  148.119995  148.699997  149.259995   58418800.0
# 2021-10-21  149.639999  147.869995  148.809998  149.479996   61421000.0
# 2021-10-22  150.179993  148.639999  149.690002  148.690002   58839600.0
#
#              Adj Close
# Date
# 2016-10-25   27.724911
# 2016-10-26   27.101248
# ...

# %%
all_data["AAPL"].keys()
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
price
# Out:
#                   AAPL         IBM        MSFT         GOOG         TSM  \
# Date
# 2016-10-25   27.724911  120.465813   56.429707   807.669983   27.099537
# 2016-10-26   27.101248  121.208351   56.096626   799.070007   26.807501
# 2016-10-27   26.840996  122.437935   55.606247   795.349976   26.429567
# 2016-10-28   26.662802  121.847099   55.393448   795.369995   26.429567
# 2016-10-31   26.620602  122.709373   55.439709   784.539978   26.713017
# ...                ...         ...         ...          ...         ...
# 2021-10-19  148.759995  141.979996  308.230011  2876.439941  116.959999
# 2021-10-20  149.259995  141.899994  307.410004  2848.300049  115.589996
# 2021-10-21  149.479996  128.330002  310.760010  2855.610107  116.290001
# 2021-10-22  148.690002  127.879997  309.160004  2772.500000  114.230003
# 2021-10-25         NaN         NaN         NaN          NaN         NaN
#
#                2330.TW     2317.TW
# Date
# 2016-10-25         NaN         NaN
# ...

# %%
type(price)
# Out:
# pandas.core.frame.DataFrame

# %%
price.columns
# Out:
# Index(['AAPL', 'IBM', 'MSFT', 'GOOG', 'TSM', '2330.TW', '2317.TW'], dtype='object')

# %%
price.keys()
# Out:
# Index(['AAPL', 'IBM', 'MSFT', 'GOOG', 'TSM', '2330.TW', '2317.TW'], dtype='object')

# %%
price["AAPL"]
# Out:
# Date
# 2016-10-25     27.724911
# 2016-10-26     27.101248
# 2016-10-27     26.840996
# 2016-10-28     26.662802
# 2016-10-31     26.620602
#                  ...
# 2021-10-19    148.759995
# 2021-10-20    149.259995
# 2021-10-21    149.479996
# 2021-10-22    148.690002
# 2021-10-25           NaN
# Name: AAPL, Length: 1296, dtype: float64

# %%
type(price["AAPL"])
# Out:
# pandas.core.series.Series

# %%
price.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
price[["GOOG", "AAPL"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
price[-300:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
price.AAPL
# Out:
# Date
# 2016-10-25     27.724911
# 2016-10-26     27.101248
# 2016-10-27     26.840996
# 2016-10-28     26.662802
# 2016-10-31     26.620602
#                  ...
# 2021-10-19    148.759995
# 2021-10-20    149.259995
# 2021-10-21    149.479996
# 2021-10-22    148.690002
# 2021-10-25           NaN
# Name: AAPL, Length: 1296, dtype: float64

# %%
price.AAPL.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
price.plot()

# %%
volume.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
price[['TSM', '2317.TW']]
# Out:
#                    TSM     2317.TW
# Date
# 2016-10-25   27.099537         NaN
# 2016-10-26   26.807501   87.669609
# 2016-10-27   26.429567   87.464783
# 2016-10-28   26.429567   86.850266
# 2016-10-31   26.713017   87.362358
# ...                ...         ...
# 2021-10-19  116.959999  107.000000
# 2021-10-20  115.589996  107.500000
# 2021-10-21  116.290001  108.000000
# 2021-10-22  114.230003  107.500000
# 2021-10-25         NaN  109.000000
#
# [1296 rows x 2 columns]

# %% [markdown]
# ## <span style="color:red"> 比較台積電以及美國 ADR TSM 的走勢 </span>

# %%
price[['TSM', '2330.TW']]
# Out:
#                    TSM     2330.TW
# Date
# 2016-10-25   27.099537         NaN
# 2016-10-26   26.807501  163.695587
# 2016-10-27   26.429567  161.131180
# 2016-10-28   26.429567  161.985977
# 2016-10-31   26.713017  161.131180
# ...                ...         ...
# 2021-10-19  116.959999  600.000000
# 2021-10-20  115.589996  598.000000
# 2021-10-21  116.290001  596.000000
# 2021-10-22  114.230003  600.000000
# 2021-10-25         NaN  594.000000
#
# [1296 rows x 2 columns]

# %%
price[['TSM', '2330.TW']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# https://davidhuang1219.pixnet.net/blog/post/324712617-台積電-adr%28tsm%29股價如何換算？adr折溢價如何計

# %%
price['arbitrage'] =  price['TSM'] * 27.87 / 5

# %%
price['2330.TW'].tail()
# Out:
# Date
# 2021-10-19    600.0
# 2021-10-20    598.0
# 2021-10-21    596.0
# 2021-10-22    600.0
# 2021-10-25    594.0
# Name: 2330.TW, dtype: float64

# %%
price[['2330.TW', 'arbitrage']].tail()
# Out:
#             2330.TW   arbitrage
# Date
# 2021-10-19    600.0  651.935035
# 2021-10-20    598.0  644.298640
# 2021-10-21    596.0  648.200465
# 2021-10-22    600.0  636.718039
# 2021-10-25    594.0         NaN

# %%
price[['TSM', '2330.TW', 'arbitrage']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## <span style="color:red"> 我們來看虛擬貨幣中乙太幣 (ETH) 對比特幣 (BTC) 的走勢 </span>

# %%
crypto = {ticker: web.get_data_yahoo(ticker)
            for ticker in ['BTC-USD','ETH-USD']}
type(crypto)
# Out:
# dict

# %%
crypto
# Out:
# {'BTC-USD':                     High           Low          Open         Close  \
#  Date
#  2016-10-24    664.424011    653.697998    654.002014    657.588013
#  2016-10-25    679.728027    657.677979    657.677979    678.304016
#  2016-10-26    688.593994    678.039978    678.213989    688.312988
#  2016-10-27    690.443970    684.161987    688.000000    689.651001
#  2016-10-28    720.401978    690.052002    690.289001    714.479004
#  ...                  ...           ...           ...           ...
#  2021-10-19  66930.390625  63610.675781  64284.585938  65992.835938
#  2021-10-20  66600.546875  62117.410156  66002.234375  62210.171875
#  2021-10-21  63715.023438  60122.796875  62237.890625  60692.265625
#  2021-10-22  61743.878906  59826.523438  60694.628906  61393.617188
#  2021-10-25  62157.734375  60730.304688  60804.234375  61995.039062
#
#                    Volume     Adj Close
#  Date
#  2016-10-24  9.037880e+07    657.588013
#  2016-10-25  8.887710e+07    678.304016
# ...

# %%
crypto.keys()
# Out:
# dict_keys(['BTC-USD', 'ETH-USD'])

# %%
crypto_price = pd.DataFrame({ticker: data['Adj Close']
                     for ticker, data in crypto.items()})
crypto_volume = pd.DataFrame({ticker: data['Volume']
                      for ticker, data in crypto.items()})

# %%
crypto_price.plot()

# %%
crypto_volume[-100:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas_datareader.data as web
all_coin = {ticker: web.get_data_yahoo(ticker)
            for ticker in ['ETH-USD', 'BTC-USD', 'ETH-BTC']}

# %%
type(all_coin)
# Out:
# dict

# %%
all_coin.keys()
# Out:
# dict_keys(['ETH-USD', 'BTC-USD', 'ETH-BTC'])

# %%
all_coin['ETH-BTC']
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2019-09-17  0.021250  0.020401  0.020315  0.020728   901590.0   0.020728
# 2019-09-18  0.021709  0.019937  0.020714  0.021554  1034448.0   0.021554
# 2019-09-19  0.021765  0.021132  0.021533  0.021416   788475.0   0.021416
# 2019-09-20  0.022052  0.021458  0.021401  0.021509   772807.0   0.021509
# 2019-09-21  0.021458  0.020619  0.021506  0.021007   775824.0   0.021007
# ...              ...       ...       ...       ...        ...        ...
# 2021-10-19  0.063123  0.060165  0.060343  0.062976   308190.0   0.062976
# 2021-10-20  0.066222  0.064439  0.063063  0.065171   453634.0   0.065171
# 2021-10-21  0.065842  0.064882  0.065193  0.065415   320188.0   0.065415
# 2021-10-22  0.067949  0.065475  0.065434  0.067949   240767.0   0.067949
# 2021-10-25  0.066725  0.066652  0.067003  0.066652   245974.0   0.066652
#
# [764 rows x 6 columns]

# %%
all_coin.items()
# Out:
# dict_items([('ETH-USD',                    High          Low         Open        Close        Volume  \
# Date
# 2016-10-24    11.993400    11.147500    11.967600    11.414000  1.931600e+07
# 2016-10-25    11.662500    11.384100    11.384100    11.532000  1.022180e+07
# 2016-10-26    11.606500    11.263500    11.531200    11.499700  1.325540e+07
# 2016-10-27    11.578400    10.953900    11.474900    11.085100  1.397150e+07
# 2016-10-28    11.198500     9.563270    11.100300    10.444600  2.707040e+07
# ...                 ...          ...          ...          ...           ...
# 2021-10-19  4167.472168  3833.288086  3877.730957  4155.992188  2.033832e+10
# 2021-10-20  4366.088379  4032.483887  4161.713379  4054.322754  2.822066e+10
# 2021-10-21  4162.975586  3908.340332  4055.686523  3970.181885  1.943294e+10
# 2021-10-22  4171.663574  3944.631836  3971.356445  4171.663574  1.478154e+10
# 2021-10-25  4138.919434  4072.063232  4082.549561  4136.122559  1.526398e+10
#
# ...

# %% [markdown]
# ## <span style="color:red"> 我們來看虛擬貨幣的走勢 </span>

# %%
price_eb = all_coin["ETH-BTC"]["Adj Close"]

# %%
price_eb.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
major_coin = {ticker: web.get_data_yahoo(ticker)
            for ticker in ['ETH-USD', 'BTC-USD']}

# %%
crypto_price = pd.DataFrame({ticker: data['Adj Close']
                     for ticker, data in major_coin.items()})

# %%
crypto_volume = pd.DataFrame({ticker: data['Volume']
                      for ticker, data in major_coin.items()})

# %%
crypto_price.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
major_coin = {ticker: web.get_data_yahoo(ticker)
            for ticker in ['ETH-USD', 'BTC-USD','ETH-BTC']}

# %%
major_coin
# Out:
# {'ETH-USD':                    High          Low         Open        Close        Volume  \
#  Date
#  2016-10-24    11.993400    11.147500    11.967600    11.414000  1.931600e+07
#  2016-10-25    11.662500    11.384100    11.384100    11.532000  1.022180e+07
#  2016-10-26    11.606500    11.263500    11.531200    11.499700  1.325540e+07
#  2016-10-27    11.578400    10.953900    11.474900    11.085100  1.397150e+07
#  2016-10-28    11.198500     9.563270    11.100300    10.444600  2.707040e+07
#  ...                 ...          ...          ...          ...           ...
#  2021-10-19  4167.472168  3833.288086  3877.730957  4155.992188  2.033832e+10
#  2021-10-20  4366.088379  4032.483887  4161.713379  4054.322754  2.822066e+10
#  2021-10-21  4162.975586  3908.340332  4055.686523  3970.181885  1.943294e+10
#  2021-10-22  4171.663574  3944.631836  3971.356445  4171.663574  1.478154e+10
#  2021-10-25  4140.120117  4072.063232  4082.549561  4140.120117  1.528661e+10
#
# ...

# %%
# expected error
major_crypto_price = pd.DataFrame({ticker: data['Adj Close']
                     for ticker, data in major_coin.items()})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHENG-~1\AppData\Local\Temp/ipykernel_3420/296801054.py in <module>
#       1 # expected error
#       2 major_crypto_price = pd.DataFrame({ticker: data['Adj Close']
# ----> 3                      for ticker, data in major_coin.items()})
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
# expected error
major_crypto_volume = pd.DataFrame({ticker: data['Volume']
                      for ticker, data in major_coin.items()})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHENG-~1\AppData\Local\Temp/ipykernel_3420/137997089.py in <module>
#       1 # expected error
#       2 major_crypto_volume = pd.DataFrame({ticker: data['Volume']
# ----> 3                       for ticker, data in major_coin.items()})
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
crypto_price.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 獨立將 ETH-BTC 的資料取出來
crypto_EB = {ticker: web.get_data_yahoo(ticker)
            for ticker in ['ETH-BTC']}
type(crypto_EB)
# Out:
# dict

# %%
crypto_EB.keys()
# Out:
# dict_keys(['ETH-BTC'])

# %%
crypto_EB.items()
# Out:
# dict_items([('ETH-BTC',                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2019-09-17  0.021250  0.020401  0.020315  0.020728   901590.0   0.020728
# 2019-09-18  0.021709  0.019937  0.020714  0.021554  1034448.0   0.021554
# 2019-09-19  0.021765  0.021132  0.021533  0.021416   788475.0   0.021416
# 2019-09-20  0.022052  0.021458  0.021401  0.021509   772807.0   0.021509
# 2019-09-21  0.021458  0.020619  0.021506  0.021007   775824.0   0.021007
# ...              ...       ...       ...       ...        ...        ...
# 2021-10-19  0.063123  0.060165  0.060343  0.062976   308190.0   0.062976
# 2021-10-20  0.066222  0.064439  0.063063  0.065171   453634.0   0.065171
# 2021-10-21  0.065842  0.064882  0.065193  0.065415   320188.0   0.065415
# 2021-10-22  0.067949  0.065475  0.065434  0.067949   240767.0   0.067949
# 2021-10-25  0.066655  0.066651  0.067003  0.066651   246287.0   0.066651
#
# [764 rows x 6 columns])])

# %%
# 這是更簡單的方法
crypto_EB["ETH-BTC"]
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2019-09-17  0.021250  0.020401  0.020315  0.020728   901590.0   0.020728
# 2019-09-18  0.021709  0.019937  0.020714  0.021554  1034448.0   0.021554
# 2019-09-19  0.021765  0.021132  0.021533  0.021416   788475.0   0.021416
# 2019-09-20  0.022052  0.021458  0.021401  0.021509   772807.0   0.021509
# 2019-09-21  0.021458  0.020619  0.021506  0.021007   775824.0   0.021007
# ...              ...       ...       ...       ...        ...        ...
# 2021-10-19  0.063123  0.060165  0.060343  0.062976   308190.0   0.062976
# 2021-10-20  0.066222  0.064439  0.063063  0.065171   453634.0   0.065171
# 2021-10-21  0.065842  0.064882  0.065193  0.065415   320188.0   0.065415
# 2021-10-22  0.067949  0.065475  0.065434  0.067949   240767.0   0.067949
# 2021-10-25  0.066655  0.066651  0.067003  0.066651   246287.0   0.066651
#
# [764 rows x 6 columns]

# %%
crypto_EB["ETH-BTC"]["Adj Close"].plot()
crypto_EB["ETH-BTC"]["Adj Close"].rolling(window=20).mean().plot()
crypto_EB["ETH-BTC"]["Adj Close"].rolling(window=60).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
crypto_EB["ETH-BTC"]["Adj Close"][-365:].plot()
crypto_EB["ETH-BTC"]["Adj Close"][-365:].rolling(window=20).mean().plot()
crypto_EB["ETH-BTC"]["Adj Close"][-365:].rolling(window=60).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>
